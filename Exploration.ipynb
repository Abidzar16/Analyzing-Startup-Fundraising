# %% [markdown]
# # Guided Project: Analyzing Startup Fundraising Deals from Crunchbase

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Data Loading

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\win10\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (0.24.2)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from -r requirements.txt (line 2)) (from versions: none)
# ERROR: No matching distribution found for sqlite3 (from -r requirements.txt (line 2))

# %%
# Import library for data loading
import pandas as pd

# %% [markdown]
# In this part, i am using pandas chunksize due to large dataset size (approximately 60 MB consist more than 50,000 rows)

# %%
data_chunks = pd.read_csv("data/crunchbase-investments.csv", chunksize = 5000, encoding='ISO-8859-1')

# %% [markdown]
# ### 1.2 Each Column's Missing Value Counts

# %%
missing_val = []
memory_usg = []

#filling missing_val and memory_usg variable
for chunk in data_chunks :
    missing_val.append(chunk.isnull().sum()) 
    # Each column's missing value counts
    memory_usg.append(chunk.memory_usage(deep=True))
    # Each column's memory footprint

# %%
concat_mvc = pd.concat(missing_val)
missing_val_comb = concat_mvc.groupby(concat_mvc.index).sum().sort_values(ascending=False)
print('Missing value per column :')
print(missing_val_comb)
# Out:
# Missing value per column :
# investor_category_code    50427
# investor_state_code       16809
# investor_city             12480
# investor_country_code     12001
# raised_amount_usd          3599
# company_category_code       643
# company_city                533
# company_state_code          492
# funding_round_type            3
# funded_year                   3
# funded_month                  3
# funded_at                     3
# funded_quarter                3
# investor_name                 2
# investor_permalink            2
# investor_region               2
# company_region                1
# company_permalink             1
# company_name                  1
# company_country_code          1
# dtype: int64

# %% [markdown]
# ### 1.3 Memory Footprint

# %%
# Each column's memory footprint
concat_mu = pd.concat(memory_usg)
memory_usg_comb = concat_mu.groupby(concat_mu.index).sum().sort_values(ascending=False)
print('Memory usage each column :')
print(memory_usg_comb.drop('Index'))

# The total memory footprint of all of the chunks combined
print('\nMemory usage Sum = {} KB'.format(memory_usg_comb.sum()))
# Out:
# Memory usage each column :
# investor_permalink        4980548
# company_permalink         4057788
# investor_name             3915666
# company_name              3591326
# funded_at                 3542185
# company_city              3505906
# company_category_code     3421104
# company_region            3411565
# funding_round_type        3410707
# investor_region           3396281
# funded_month              3383584
# funded_quarter            3383584
# company_country_code      3172176
# company_state_code        3106051
# investor_city             2885083
# investor_country_code     2647292
# investor_state_code       2476607
# investor_category_code     622424
# raised_amount_usd          422960
# funded_year                422960
# dtype: int64
#
# Memory usage Sum = 59756717 KB

# %% [markdown]
# ### 1.4 Eliminating Column(s) that aren't Useful for Analysis

# %%
# print sample from random chunk
chunk.sample(10)
# Out:
#               company_permalink     company_name company_category_code  \
# 50159         /company/cardpool         Cardpool                   web
# 52420         /company/storenvy         Storenvy             ecommerce
# 52325      /company/checkpoints      CheckPoints                mobile
# 51979           /company/justme          just.me                mobile
# 51846       /company/myminilife       MyMiniLife           games_video
# 50511          /company/adility          Adility           advertising
# 51301       /company/circle-inc       Circle Inc                social
# 50813  /company/t5-data-centers  T5 Data Centers              security
# 50541      /company/kickstarter      Kickstarter               finance
# 50929     /company/hoteltonight     HotelTonight                mobile
#
#       company_country_code company_state_code company_region   company_city  \
# 50159                  USA                 CA         SF Bay  San Francisco
# 52420                  USA                 CA         SF Bay  San Francisco
# 52325                  USA                 CA    Los Angeles    Los Angeles
# 51979                  USA                 CA         SF Bay      Palo Alto
# 51846                  USA                 CA         SF Bay      Palo Alto
# 50511                  USA                 CA         SF Bay  San Francisco
# 51301                  USA                 CA         SF Bay      Palo Alto
# 50813                  USA                 GA        Atlanta        Atlanta
# 50541                  USA                 NY       New York       New York
# 50929                  USA                 CA         SF Bay  San Francisco
#
#             investor_permalink    investor_name  investor_category_code  \
# 50159     /person/nils-johnson     Nils Johnson                     NaN
# 52420     /person/tom-rosedale     Tom Rosedale                     NaN
# 52325     /person/todd-dipaola     Todd Dipaola                     NaN
# 51979   /person/steve-mcarthur   Steve McArthur                     NaN
# 51846      /person/sizhao-yang      Sizhao Yang                     NaN
# 50511     /person/peter-bordes     Peter Bordes                     NaN
# 51301       /person/ron-conway       Ron Conway                     NaN
# 50813    /person/raymond-james    Raymond James                     NaN
# 50541  /person/peter-hershberg  Peter Hershberg                     NaN
# 50929    /person/rich-barton-2      Rich Barton                     NaN
#
#        investor_country_code  investor_state_code investor_region  \
# 50159                    NaN                  NaN         unknown
# 52420                    NaN                  NaN         unknown
# 52325                    NaN                  NaN         unknown
# 51979                    NaN                  NaN         unknown
# 51846                    NaN                  NaN         unknown
# 50511                    NaN                  NaN         unknown
# 51301                    NaN                  NaN         unknown
# 50813                    NaN                  NaN         unknown
# 50541                    NaN                  NaN         unknown
# 50929                    NaN                  NaN         unknown
#
#        investor_city funding_round_type   funded_at funded_month  \
# 50159            NaN              angel  2010-01-01      2010-01
# 52420            NaN           series-a  2011-01-27      2011-01
# 52325            NaN           series-a  2010-05-01      2010-05
# 51979            NaN              angel  2011-07-30      2011-07
# 51846            NaN              angel  2006-11-15      2006-11
# 50511            NaN           series-a  2011-09-06      2011-09
# 51301            NaN              angel  2011-01-01      2011-01
# 50813            NaN              other  2013-05-14      2013-05
# 50541            NaN            venture  2011-03-18      2011-03
# 50929            NaN           series-a  2011-05-10      2011-05
#
#       funded_quarter  funded_year  raised_amount_usd
# 50159        2010-Q1         2010                NaN
# 52420        2011-Q1         2011          1525000.0
# 52325        2010-Q2         2010          1000000.0
# 51979        2011-Q3         2011           500000.0
# 51846        2006-Q4         2006            10000.0
# 50511        2011-Q3         2011                NaN
# 51301        2011-Q1         2011          1000000.0
# 50813        2013-Q2         2013        113000000.0
# 50541        2011-Q1         2011         10000000.0
# 50929        2011-Q2         2011          3585000.0

# %%
drop_cols = ['investor_permalink','company_permalink','investor_category_code','funded_year','funded_month','funded_quarter']

# %% [markdown]
# Explanation :
# 1. Permalink columns ('investor_permalink' and 'company_permalink') can't be used for analysis
# 2. 'investor_category_code" is column with highest missing value, therefore can't be used for analysis
# 3. 'funded_year', 'funded_month' and 'funded_quarter' is considered redundant and can be substituted by 'funded_at'

# %% [markdown]
# ## 2. Selecting Data Types

# %% [markdown]
# ### 2.1 Identify the types for each column per chunk

# %%
data_chunks = pd.read_csv("data/crunchbase-investments.csv", chunksize = 5000, encoding='ISO-8859-1')
col_types = {}

for chunk in data_chunks:
    chunk.drop(columns=drop_cols, inplace = True)
    for col in chunk.columns:
        if col not in col_types:
            col_types[col] = [str(chunk.dtypes[col])]
        else:
            col_types[col].append(str(chunk.dtypes[col]))

# %%
col_types_df = pd.DataFrame(col_types, columns = chunk.columns)
col_types_df.index.name = "chunk"

# %%
col_types_df
# Out:
#       company_name company_category_code company_country_code  \
# chunk
# 0           object                object               object
# 1           object                object               object
# 2           object                object               object
# 3           object                object               object
# 4           object                object               object
# 5           object                object               object
# 6           object                object               object
# 7           object                object               object
# 8           object                object               object
# 9           object                object               object
# 10          object                object               object
#
#       company_state_code company_region company_city investor_name  \
# chunk
# 0                 object         object       object        object
# 1                 object         object       object        object
# 2                 object         object       object        object
# 3                 object         object       object        object
# 4                 object         object       object        object
# 5                 object         object       object        object
# 6                 object         object       object        object
# 7                 object         object       object        object
# 8                 object         object       object        object
# 9                 object         object       object        object
# 10                object         object       object        object
#
#       investor_country_code investor_state_code investor_region investor_city  \
# chunk
# 0                    object              object          object        object
# 1                    object              object          object        object
# 2                    object              object          object        object
# 3                    object              object          object        object
# 4                    object              object          object        object
# 5                    object              object          object        object
# 6                    object              object          object        object
# 7                    object              object          object        object
# 8                    object              object          object        object
# 9                   float64             float64          object       float64
# 10                  float64             float64          object       float64
#
#       funding_round_type funded_at raised_amount_usd
# chunk
# 0                 object    object           float64
# 1                 object    object           float64
# 2                 object    object           float64
# 3                 object    object           float64
# 4                 object    object           float64
# 5                 object    object           float64
# 6                 object    object           float64
# 7                 object    object           float64
# 8                 object    object           float64
# 9                 object    object           float64
# 10                object    object           float64

# %%
# Identify the unique types for each columns
uniq_col_types = {}
for k,v in col_types.items():
    uniq_col_types[k] = set(col_types[k])
uniq_col_types
# Out:
# {'company_name': {'object'},
#  'company_category_code': {'object'},
#  'company_country_code': {'object'},
#  'company_state_code': {'object'},
#  'company_region': {'object'},
#  'company_city': {'object'},
#  'investor_name': {'object'},
#  'investor_country_code': {'float64', 'object'},
#  'investor_state_code': {'float64', 'object'},
#  'investor_region': {'object'},
#  'investor_city': {'float64', 'object'},
#  'funding_round_type': {'object'},
#  'funded_at': {'object'},
#  'raised_amount_usd': {'float64'}}

# %% [markdown]
# ### 2.2 Find more space efficient types for every columns

# %% [markdown]
# #### 2.2.1 Find Columns that can be Converted into Category and Datetime

# %%
# Find the Number of Unique Values in Each Non-Numeric Column
df = pd.read_csv("data/crunchbase-investments.csv", encoding='ISO-8859-1', low_memory=False)
df.drop(columns=drop_cols, inplace = True)

print("\nMany unique values in each columns:")
for col in df.columns:
    print("{} : {}".format(col,len(df[col].unique())))
# Out:
# Many unique values in each columns:
# company_name : 11574
# company_category_code : 44
# company_country_code : 3
# company_state_code : 51
# company_region : 547
# company_city : 1230
# investor_name : 10466
# investor_country_code : 73
# investor_state_code : 51
# investor_region : 586
# investor_city : 991
# funding_round_type : 10
# funded_at : 2809
# raised_amount_usd : 1459

# %% [markdown]
# If the amount of unique strings in column cover less than half the total amount of strings, the column is suitable to convert into pandas category column type. Keep in mind that column with category data type restricts adding unknown values to that column.

# %%
def optimize_objects(df,date_time_column):
    for col in df.select_dtypes(include=['object']):
        if col not in date_time_column:
            num_unique_values = len(df[col].unique())
            num_total_values = len(df[col])
            if float(num_unique_values) / num_total_values < 0.5:
                df[col] = df[col].astype('category')
        else:
            df[col] = pd.to_datetime(df[col])
    return df

# %% [markdown]
# ## 3. The Total Memory Footprint After Data Cleaning

# %%
data_chunks = pd.read_csv("data/crunchbase-investments.csv", chunksize = 5000, encoding='ISO-8859-1')

memory_usg = []

#filling missing_val and memory_usg variable
for chunk in data_chunks :
    chunk.drop(columns=drop_cols, inplace = True)
    chunk = optimize_objects(chunk,['funded_at'])
    memory_usg.append(chunk.memory_usage(deep=True))
    # Each column's memory footprint

# %%
# Each column's memory footprint
concat_mu = pd.concat(memory_usg)
memory_usg_comb = concat_mu.groupby(concat_mu.index).sum().sort_values(ascending=False)
print('Memory usage each column :')
print(memory_usg_comb.drop('Index'))

# The total memory footprint of all of the chunks combined
print('\nMemory usage Sum = {} KB'.format(memory_usg_comb.sum()))
# Out:
# Memory usage each column :
# company_name             3489096
# investor_name            1221123
# company_city              654349
# raised_amount_usd         422960
# funded_at                 422960
# investor_city             370095
# company_region            332777
# investor_region           227785
# investor_state_code       138773
# investor_country_code     138080
# company_category_code      96448
# company_state_code         96101
# funding_round_type         62126
# company_country_code       54474
# dtype: int64
#
# Memory usage Sum = 7728067 KB

# %% [markdown]
# After dropping six columns and converting several columns into categorical and datetime datatype, The total memory usage have dropped from 59.76 MB to 7.72 MB, improving over 87%. So eliminating and converting columns was definitely worth it.

# %% [markdown]
# ## 4. Loading Chunks Into SQLite

# %%
import sqlite3
conn = sqlite3.connect('data/crunchbase.db')
data_chunks = pd.read_csv('data/crunchbase-investments.csv', chunksize=5000, encoding='ISO-8859-1')

# uncomment two lines below if you want to renew (not append) 'investments' table
cur = conn.cursor()
cur.execute("""DROP TABLE investments;""")

for chunk in data_chunks:
    chunk.drop(columns=drop_cols, inplace = True)
    chunk = optimize_objects(chunk,['funded_at'])
    chunk.to_sql("investments", conn, if_exists='append', index=False)
    
conn.commit()
conn.close()

# %%
# !wc data/crunchbase.db
# Out:
#    11299   589499 14204928 data/crunchbase.db

# %% [markdown]
# ## 5. Data Exploration and Analysis Using SQLite

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data/crunchbase.db')
cur = conn.cursor()
query = ("""SELECT * FROM investments """)
pd.read_sql(query, conn)
# Out:
#                           company_name company_category_code  \
# 0                             AdverCar           advertising
# 1                           LaunchGram                  news
# 2                                 uTaP             messaging
# 3                             ZoopShop              software
# 4                             eFuneral                   web
# 5                                Tackk                   web
# 6                             Acclaimd             analytics
# 7                             Acclaimd             analytics
# 8                             ToVieFor             ecommerce
# 9                             OHK Labs                sports
# 10                              Lovely           real_estate
# 11                        peerTransfer               finance
# 12                            spotdock                   web
# 13                   Fisker Automotive            automotive
# 14                   Fisker Automotive            automotive
# 15                      MetroFlats.com                travel
# 16                            MesoCoat              nanotech
# 17                           Trilliant              hardware
# 18                        Power Assure       network_hosting
# 19                           Trilliant              hardware
# 20                           ECOtality             cleantech
# 21                              Evalve               biotech
# 22                              Ovalis               biotech
# 23              Alvine Pharmaceuticals               biotech
# 24                    Avaxia Biologics               biotech
# 25              AuraSense Therapeutics               biotech
# 26                        LibraryThing                   web
# 27                           HelioVolt             cleantech
# 28     Airband Communications Holdings                mobile
# 29                                Xand              software
# ...                                ...                   ...
# 52840                           Meddik                health
# 52841                       Blue Apron           hospitality
# 52842                           ChatID                mobile
# 52843          Breakthrough Behavioral                health
# 52844                            Plaid              software
# 52845                         PokitDok                mobile
# 52846                        Fitocracy                   web
# 52847                           Square                mobile
# 52848                          MixRank           advertising
# 52849                        Socialcam                mobile
# 52850                           Nuzzel                  news
# 52851                        ThirdLove             ecommerce
# 52852                            MXD3D                   web
# 52853                            MXD3D                   web
# 52854                          Verious                mobile
# 52855                       Identified             analytics
# 52856                      HaulerDeals               fashion
# 52857                    When You Wish             nonprofit
# 52858                         Farmeron             analytics
# 52859              Theraclone Sciences               biotech
# 52860                        SimpleGeo           advertising
# 52861                          Open Me             ecommerce
# 52862               Comprehend Systems            enterprise
# 52863                         Payoneer                 other
# 52864                         Outbrain                   web
# 52865                    Garantia Data            enterprise
# 52866                       DudaMobile                mobile
# 52867                       SiteBrains              software
# 52868               Comprehend Systems            enterprise
# 52869                      SmartThings                mobile
#
#       company_country_code company_state_code         company_region  \
# 0                      USA                 CA                 SF Bay
# 1                      USA                 CA                 SF Bay
# 2                      USA               None  United States - Other
# 3                      USA                 OH               Columbus
# 4                      USA                 OH              Cleveland
# 5                      USA                 OH              Cleveland
# 6                      USA                 OH               Columbus
# 7                      USA                 OH               Columbus
# 8                      USA                 NY               New York
# 9                      USA                 FL             Palm Beach
# 10                     USA                 CA                 SF Bay
# 11                     USA                 MA                 Boston
# 12                     USA                 NY               New York
# 13                     USA                 CA            Los Angeles
# 14                     USA                 CA            Los Angeles
# 15                     USA                 NJ            Cedar Grove
# 16                     USA                 OH              Cleveland
# 17                     USA                 CA                 SF Bay
# 18                     USA                 CA                 SF Bay
# 19                     USA                 CA                 SF Bay
# 20                     USA                 CA                 SF Bay
# 21                     USA                 CA                 SF Bay
# 22                     USA                 CA                 SF Bay
# 23                     USA                 CA                 SF Bay
# 24                     USA                 MA                 Boston
# 25                     USA                 IL                Chicago
# 26                     USA                 ME               Portland
# 27                     USA                 TX                 Austin
# 28                     USA                 TX                 Dallas
# 29                     USA                 NY               New York
# ...                    ...                ...                    ...
# 52840                  USA                 NY               New York
# 52841                  USA                 NY               New York
# 52842                  USA                 NY               New York
# 52843                  USA                 CA                 SF Bay
# 52844                  USA                 CA                 SF Bay
# 52845                  USA                 CA                 SF Bay
# 52846                  USA                 NY               New York
# 52847                  USA                 CA                 SF Bay
# 52848                  USA                 CA                 SF Bay
# 52849                  USA                 CA     Santa Clara County
# 52850                  USA                 CA                 SF Bay
# 52851                  USA                 CA                 SF Bay
# 52852                  USA                 CA                 SF Bay
# 52853                  USA                 CA                 SF Bay
# 52854                  USA                 CA                 SF Bay
# 52855                  USA                 CA                 SF Bay
# 52856                  USA                 CA            Los Angeles
# 52857                  USA                 CA            Los Angeles
# 52858                  USA                 CA                 SF Bay
# 52859                  USA                 WA                Seattle
# 52860                  USA                 CA                 SF Bay
# 52861                  USA                 CA            Los Angeles
# 52862                  USA                 CA                 SF Bay
# 52863                  USA                 NY               New York
# 52864                  USA                 NY               New York
# 52865                  USA                 CA                 SF Bay
# 52866                  USA                 CA                 SF Bay
# 52867                  USA                 CA                 SF Bay
# 52868                  USA                 CA                 SF Bay
# 52869                  USA                 DC                unknown
#
#              company_city                             investor_name  \
# 0           San Francisco                         1-800-FLOWERS.COM
# 1           Mountain View                               10Xelerator
# 2                    None                               10Xelerator
# 3                columbus                               10Xelerator
# 4               Cleveland                               10Xelerator
# 5               Cleveland                               10Xelerator
# 6                Columbus                               10Xelerator
# 7                Columbus                               10Xelerator
# 8                New York  2010 NYU Stern Business Plan Competition
# 9              Boca Raton                           22Hundred Group
# 10          San Francisco                                     3taps
# 11                 Boston                                  500 Hats
# 12                    NYC                              9mmedia, LLC
# 13                 Irvine                              A123 Systems
# 14                 Irvine                              A123 Systems
# 15            Cedar Grove                            AA Investments
# 16                 Euclid                                    Abakan
# 17           Redwood City                                       ABB
# 18            Santa Clara                                       ABB
# 19           Redwood City                                       ABB
# 20          San Francisco                                       ABB
# 21             Menlo Park                               Abbott Labs
# 22          Mountain View                               Abbott Labs
# 23             San Carlos                                    AbbVie
# 24              Lexington                                    AbbVie
# 25               Evanston                                    AbbVie
# 26               Portland                                  AbeBooks
# 27                 Austin                             Abengoa Solar
# 28                 Dallas                             ABRY Partners
# 29              Hawthorne                             ABRY Partners
# ...                   ...                                       ...
# 52840            New York                             Zach Weinberg
# 52841            Brooklyn                             Zach Weinberg
# 52842            New York                             Zach Weinberg
# 52843        Redwood City                             Zach Weinberg
# 52844       San Francisco                             Zach Weinberg
# 52845          Menlo Park                              Zach Zeitlin
# 52846            New York                            Zachary Aarons
# 52847       San Francisco                             Zachary Bogue
# 52848       San Francisco                             Zachary Bogue
# 52849  Santa Clara County                             Zachary Bogue
# 52850       San Francisco                             Zachary Bogue
# 52851       San Francisco                             Zachary Bogue
# 52852       San Francisco                                Zaid Ayoub
# 52853       San Francisco                                Zaid Ayoub
# 52854          San Carlos                                 Zain Khan
# 52855       San Francisco                                  Zao Yang
# 52856         Los Angeles                                  Zaw Thet
# 52857      Marina Del Rey                              Zelda Marzec
# 52858       Mountain View                            Zeljko Mataija
# 52859             Seattle                             Zenyaku Kogyo
# 52860       San Francisco                                Ziv Navoth
# 52861         Los Angeles                                Ziver Birg
# 52862           Palo Alto                                 Zod Nazem
# 52863            New York                               Zohar Gilon
# 52864       New York City                               Zohar Gilon
# 52865         Santa Clara                               Zohar Gilon
# 52866           Palo Alto                               Zohar Gilon
# 52867       San Francisco                              zohar israel
# 52868           Palo Alto                           Zorba Lieberman
# 52869         Minneapolis                              Zorik Gordon
#
#       investor_country_code investor_state_code  investor_region  \
# 0                       USA                  NY         New York
# 1                       USA                  OH         Columbus
# 2                       USA                  OH         Columbus
# 3                       USA                  OH         Columbus
# 4                       USA                  OH         Columbus
# 5                       USA                  OH         Columbus
# 6                       USA                  OH         Columbus
# 7                       USA                  OH         Columbus
# 8                      None                None          unknown
# 9                      None                None          unknown
# 10                      USA                  CA           SF Bay
# 11                      USA                  CA           SF Bay
# 12                     None                None          unknown
# 13                      USA                  MA           Boston
# 14                      USA                  MA           Boston
# 15                      BMU                None  Bermuda - Other
# 16                      USA                  FL            Miami
# 17                      CHE                None           Zurich
# 18                      CHE                None           Zurich
# 19                      CHE                None           Zurich
# 20                      CHE                None           Zurich
# 21                      USA                  IL          Chicago
# 22                      USA                  IL          Chicago
# 23                      USA                  IL          Chicago
# 24                      USA                  IL          Chicago
# 25                      USA                  IL          Chicago
# 26                      CAN                None         Victoria
# 27                      ESP                None          Sevilla
# 28                      USA                  MA           Boston
# 29                      USA                  MA           Boston
# ...                     ...                 ...              ...
# 52840                  None                None          unknown
# 52841                  None                None          unknown
# 52842                  None                None          unknown
# 52843                  None                None          unknown
# 52844                  None                None          unknown
# 52845                  None                None          unknown
# 52846                  None                None          unknown
# 52847                  None                None          unknown
# 52848                  None                None          unknown
# 52849                  None                None          unknown
# 52850                  None                None          unknown
# 52851                  None                None          unknown
# 52852                  None                None          unknown
# 52853                  None                None          unknown
# 52854                  None                None          unknown
# 52855                  None                None          unknown
# 52856                  None                None          unknown
# 52857                  None                None          unknown
# 52858                  None                None          unknown
# 52859                  None                None          unknown
# 52860                  None                None          unknown
# 52861                  None                None          unknown
# 52862                  None                None          unknown
# 52863                  None                None          unknown
# 52864                  None                None          unknown
# 52865                  None                None          unknown
# 52866                  None                None          unknown
# 52867                  None                None          unknown
# 52868                  None                None          unknown
# 52869                  None                None          unknown
#
#        investor_city funding_round_type            funded_at  \
# 0           New York           series-a  2012-10-30 00:00:00
# 1           Columbus              other  2012-01-23 00:00:00
# 2           Columbus              other  2012-01-01 00:00:00
# 3           Columbus              angel  2012-02-15 00:00:00
# 4           Columbus              other  2011-09-08 00:00:00
# 5           Columbus              other  2012-02-01 00:00:00
# 6           Columbus              angel  2012-06-01 00:00:00
# 7           Columbus              angel  2012-08-07 00:00:00
# 8               None              angel  2010-04-01 00:00:00
# 9               None              angel  2011-09-01 00:00:00
# 10     San Francisco           series-a  2012-10-01 00:00:00
# 11         Palo Alto              angel  2010-10-28 00:00:00
# 12              None              angel  2012-01-10 00:00:00
# 13         Watertown           series-a  2010-05-01 00:00:00
# 14         Watertown            venture  2011-02-22 00:00:00
# 15              None              angel  2010-08-18 00:00:00
# 16             Miami            venture  2009-12-14 00:00:00
# 17            Zurich           series-b  2010-07-15 00:00:00
# 18            Zurich            venture  2010-09-20 00:00:00
# 19            Zurich            venture  2010-12-21 00:00:00
# 20            Zurich            venture  2011-01-09 00:00:00
# 21       Des Plaines          series-c+  2007-11-27 00:00:00
# 22       Des Plaines           series-b  2007-01-30 00:00:00
# 23           Chicago     private-equity  2013-05-14 00:00:00
# 24           Chicago           series-b  2013-06-07 00:00:00
# 25           Chicago           series-b  2013-07-31 00:00:00
# 26          Victoria           series-a  2006-05-16 00:00:00
# 27           Sevilla           series-b  2007-10-23 00:00:00
# 28            Boston            venture  2011-08-11 00:00:00
# 29            Boston              other  2013-09-12 00:00:00
# ...              ...                ...                  ...
# 52840           None              angel  2012-05-24 00:00:00
# 52841           None           series-a  2013-02-19 00:00:00
# 52842           None              angel  2012-01-01 00:00:00
# 52843           None              angel  2012-08-13 00:00:00
# 52844           None           series-a  2013-09-19 00:00:00
# 52845           None              angel  2012-07-12 00:00:00
# 52846           None              angel  2011-09-01 00:00:00
# 52847           None           series-a  2009-11-01 00:00:00
# 52848           None           series-a  2011-11-18 00:00:00
# 52849           None              angel  2012-04-30 00:00:00
# 52850           None            venture  2012-11-15 00:00:00
# 52851           None           series-a  2012-12-01 00:00:00
# 52852           None              angel  2012-01-01 00:00:00
# 52853           None              angel  2011-01-01 00:00:00
# 52854           None              angel  2011-05-30 00:00:00
# 52855           None           series-b  2012-06-05 00:00:00
# 52856           None              angel  2012-10-31 00:00:00
# 52857           None           series-a  2011-02-01 00:00:00
# 52858           None              angel  2010-10-01 00:00:00
# 52859           None           series-b  2013-03-25 00:00:00
# 52860           None              other  2009-11-10 00:00:00
# 52861           None              angel  2013-08-01 00:00:00
# 52862           None           series-a  2013-07-11 00:00:00
# 52863           None           series-a  2005-01-01 00:00:00
# 52864           None           series-b  2009-02-11 00:00:00
# 52865           None           series-a  2012-08-08 00:00:00
# 52866           None          series-c+  2013-04-08 00:00:00
# 52867           None              angel  2010-08-01 00:00:00
# 52868           None           series-a  2013-07-11 00:00:00
# 52869           None           series-a  2012-12-04 00:00:00
#
#        raised_amount_usd
# 0              2000000.0
# 1                20000.0
# 2                20000.0
# 3                20000.0
# 4                20000.0
# 5                20000.0
# 6                20000.0
# 7                70000.0
# 8                75000.0
# 9               100000.0
# 10             2000000.0
# 11             1100000.0
# 12              600000.0
# 13           189000000.0
# 14           150000000.0
# 15                   NaN
# 16                   NaN
# 17           106000000.0
# 18             1500000.0
# 19                   NaN
# 20            10000000.0
# 21            60000000.0
# 22             6600000.0
# 23            70000000.0
# 24            11500000.0
# 25                   NaN
# 26                   NaN
# 27           101000000.0
# 28            20000000.0
# 29           200000000.0
# ...                  ...
# 52840           750000.0
# 52841          3000000.0
# 52842                NaN
# 52843           900000.0
# 52844          2800000.0
# 52845          1300000.0
# 52846           250000.0
# 52847         10000000.0
# 52848          1500000.0
# 52849                NaN
# 52850          1700000.0
# 52851          5600000.0
# 52852           300000.0
# 52853           300000.0
# 52854           800000.0
# 52855         21000000.0
# 52856          1250000.0
# 52857          1500000.0
# 52858            15000.0
# 52859          8000000.0
# 52860           195000.0
# 52861                NaN
# 52862          8400000.0
# 52863          2000000.0
# 52864         12000000.0
# 52865          3800000.0
# 52866         10300000.0
# 52867           350000.0
# 52868          8400000.0
# 52869          3000000.0
#
# [52870 rows x 14 columns]

# %% [markdown]
# ### 5.1 Proportion of the total amount of funds raised

# %% [markdown]
# #### 5.1.1 Top 10% Company

# %%
query = ("""SELECT SUM(sum_all)
FROM (
    SELECT SUM(raised_amount_usd) AS sum_all
    FROM investments
    GROUP BY company_name
    ORDER BY SUM(raised_amount_usd) DESC 
    LIMIT 1157
) AS T""")
pd.read_sql(query, conn)
# Out:
#    SUM(sum_all)
# 0  4.576313e+11

# %% [markdown]
# #### 5.1.2 Top 1% Company

# %%
query = ("""SELECT SUM(sum_all)
FROM (
    SELECT SUM(raised_amount_usd) AS sum_all
    FROM investments
    GROUP BY company_name
    ORDER BY SUM(raised_amount_usd) DESC 
    LIMIT 116
) AS T""")
pd.read_sql(query, conn)
# Out:
#    SUM(sum_all)
# 0  1.793735e+11

# %% [markdown]
# #### 5.1.3 Bottom 10% Company

# %%
query = ("""SELECT SUM(sum_all)
FROM (
    SELECT SUM(raised_amount_usd) AS sum_all
    FROM investments
    WHERE raised_amount_usd iS NOT NULL
    GROUP BY company_name
    ORDER BY SUM(raised_amount_usd) ASC 
    LIMIT 1157
) AS T""")
pd.read_sql(query, conn)
# Out:
#    SUM(sum_all)
# 0   252174228.0

# %% [markdown]
# #### 5.1.4 Bottom 1% Company

# %%
query = ("""SELECT SUM(sum_all)
FROM (
    SELECT SUM(raised_amount_usd) AS sum_all
    FROM investments
    WHERE raised_amount_usd iS NOT NULL
    GROUP BY company_name
    ORDER BY SUM(raised_amount_usd) ASC 
    LIMIT 116
) AS T""")
pd.read_sql(query, conn)
# Out:
#    SUM(sum_all)
# 0     1741100.0

# %% [markdown]
# ### 5.2 Which category of company attracted the most investments?

# %%
query = ("""SELECT company_category_code, SUM(raised_amount_usd)
FROM investments 
GROUP BY company_category_code 
ORDER BY SUM(raised_amount_usd) DESC 
LIMIT 10""")
pd.read_sql(query, conn)
# Out:
#   company_category_code  SUM(raised_amount_usd)
# 0               biotech            1.103964e+11
# 1              software            7.308452e+10
# 2                mobile            6.477738e+10
# 3             cleantech            5.270523e+10
# 4            enterprise            4.586093e+10
# 5                   web            4.014326e+10
# 6               medical            2.536711e+10
# 7           advertising            2.507666e+10
# 8             ecommerce            2.256722e+10
# 9       network_hosting            2.241968e+10

# %% [markdown]
# ### 5.3 Which investor contributed the most money (across all startups)?

# %%
query = ("""SELECT DISTINCT investor_name, SUM(raised_amount_usd)
FROM investments
GROUP BY investor_name
ORDER BY SUM(raised_amount_usd) DESC 
LIMIT 10""")
pd.read_sql(query, conn)
# Out:
#                       investor_name  SUM(raised_amount_usd)
# 0  Kleiner Perkins Caufield & Byers            1.121783e+10
# 1         New Enterprise Associates            9.692542e+09
# 2                    Accel Partners            6.472126e+09
# 3                     Goldman Sachs            6.375459e+09
# 4                   Sequoia Capital            6.039402e+09
# 5                             Intel            5.969200e+09
# 6                            Google            5.808800e+09
# 7                       Time Warner            5.730000e+09
# 8                           Comcast            5.669000e+09
# 9                 Greylock Partners            4.960983e+09

# %% [markdown]
# ### 5.4 Which investors contributed the most money per startup?

# %%
query = ("""SELECT investor_name, company_name, SUM(raised_amount_usd)
FROM investments
GROUP BY company_name
ORDER BY SUM(raised_amount_usd) DESC
LIMIT 10""")
pd.read_sql(query, conn)
# Out:
#             investor_name       company_name  SUM(raised_amount_usd)
# 0             BrightHouse          Clearwire            2.968000e+10
# 1          Accel Partners            Groupon            1.018540e+10
# 2             Beck Energy          Nanosolar            4.505000e+09
# 3               Microsoft           Facebook            4.154100e+09
# 4                  Google       SurveyMonkey            3.250000e+09
# 5                  Google              Zynga            2.886013e+09
# 6            A123 Systems  Fisker Automotive            2.788000e+09
# 7            Y Combinator            Dropbox            2.764400e+09
# 8                  Amazon       LivingSocial            2.685000e+09
# 9  Marlin Equity Partners          sigmacare            2.600000e+09

# %% [markdown]
# ### 5.5 Which funding round was the most popular? Which was the least popular?

# %%
query = ("""SELECT funding_round_type, SUM(raised_amount_usd) FROM investments 
GROUP BY funding_round_type 
ORDER BY SUM(raised_amount_usd) DESC""")
pd.read_sql(query, conn)
# Out:
#   funding_round_type  SUM(raised_amount_usd)
# 0          series-c+            2.657535e+11
# 1            venture            1.305565e+11
# 2           series-b            1.283268e+11
# 3           series-a            8.654215e+10
# 4           post-ipo            3.091760e+10
# 5              other            1.850726e+10
# 6     private-equity            1.615988e+10
# 7              angel            4.962075e+09
# 8       crowdfunding            6.491500e+06
# 9               None                     NaN

# %%
# Close connection
conn.close()
